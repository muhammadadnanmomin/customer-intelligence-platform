# %% [markdown]
# # Customer Lifetime Value Prediction

# %%
# TODO:
# 1. Prepare CLV training data.
# 2. Train regression models.
# 3. Evaluate with MAE, RMSE, R-squared.
# 4. Save CLV model artifacts.
