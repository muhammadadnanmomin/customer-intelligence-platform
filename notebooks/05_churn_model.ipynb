# %% [markdown]
# # Churn Prediction Model

# %%
# TODO:
# 1. Prepare training data.
# 2. Train XGBoost / LightGBM classifiers.
# 3. Evaluate with AUC-ROC, precision, recall.
# 4. Save trained model artifacts.
